# %% [markdown]
# <a href="https://colab.research.google.com/github/yoElephant/yoElephant/blob/main/Circuit_Charging_LiamStone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Example data points
x = [10.09, 20.13, 30.09, 40.09, 50.28, 60.09, 70.19, 80.14, 90.19, 100.14, 110.09, 120.19]
y = [0.0001, 4.248, 6.92, 8.53, 9.58, 10.26, 10.66, 11.11, 11.22, 11.30, 11.35, 11.38]
[10.09, 20.13, 30.09, 40.09, 50.28, 60.09, 70.19, 80.14, 90.19, 100.14, 110.09, 120.19]
plt.scatter(x, y, color='blue')

plt.title("Voltage vs Time")
plt.xlabel("Time")
plt.ylabel("Voltage")

plt.grid(True)
plt.show()
