# %% [markdown]
# <a href="https://colab.research.google.com/github/yoElephant/yoElephant/blob/main/Circuit_ChargingAndDischarging_LiamStone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Example data points
x = [10.09, 20.13, 30.09, 40.09, 50.28, 60.09, 70.19, 80.14, 90.19, 100.14, 110.09, 120.19]
y = [0.0001, 4.248, 6.92, 8.53, 9.58, 10.26, 10.66, 11.11, 11.22, 11.30, 11.35, 11.38]

plt.scatter(x, y, color='blue')

plt.title("Voltage vs Time: Charging")
plt.xlabel("Time")
plt.ylabel("Voltage")

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data points
x = [0, 10.09, 20.19, 30.13, 40.18, 50.13, 60.09, 70.19, 80.14, 90.14, 100.13, 110.09, 120.13]
y = [11.45, 7.17, 4.543, 2.881, 1.833, 1.171, 0.761, 0.491, 0.319, 0.209, 0.137, 0.094, 0.064]

plt.scatter(x, y, color='blue')

plt.title("Voltage vs Time: Discharging")
plt.xlabel("Time")
plt.ylabel("Voltage")

plt.grid(True)
plt.show()
